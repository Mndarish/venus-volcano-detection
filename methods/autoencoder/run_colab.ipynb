# %% [markdown]
# # Autoencoder (Reconstruction Error) — Colab runner
#
# **Status: investigated and ruled out.** Kept for reproducibility of the negative result — reconstruction error separates volcanoes from background *backwards* (see methods/autoencoder/README.md). For the shipped detector, use methods/supervised instead.
#
# This notebook just clones the repo and calls the method's `train.py` / `evaluate.py`. All the actual logic lives in the repo (`common/`, `methods/autoencoder/`), not here — edit those files, not this notebook.

# %% [markdown]
# ## 1. Clone the repo

# %%
REPO_URL = "https://github.com/<your-username>/<your-repo>.git"  # <-- fill in
# !git clone $REPO_URL project
# %cd project

# %% [markdown]
# ## 2. Install dependencies

# %%
# !pip install -q -r requirements.txt

# %% [markdown]
# ## 3. Verify data + pipeline
#
# Data is expected to already be committed under `data/` (`data/Images`, `data/GroundTruths`, `data/Tables`). If you're pointing at data mounted elsewhere (e.g. Google Drive), set `VOLCANO_DATA_DIR` before running the cell below.

# %%
import os
# os.environ["VOLCANO_DATA_DIR"] = "/content/drive/MyDrive/..."  # optional override

# !python scripts/verify_setup.py

# %% [markdown]
# ## 4. Train — Autoencoder (Reconstruction Error)

# %%
# !python -m methods.autoencoder.train

# %% [markdown]
# ## 5. Evaluate — Autoencoder (Reconstruction Error)

# %%
# !python -m methods.autoencoder.evaluate
